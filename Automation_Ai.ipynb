# %%
import cv2
import os
from cvzone.HandTrackingModule import HandDetector

# Setup
cap = cv2.VideoCapture(0)
detector = HandDetector(detectionCon=0.8, maxHands=1)

while True:
    success, img = cap.read()
    if not success:
        print("Camera error")
        break

    hands, img = detector.findHands(img)

    if hands:
        hand = hands[0]
        fingers = detector.fingersUp(hand)
        print("Fingers Up:", fingers)

        if fingers == [1, 1, 1, 1, 1]:
            print("Opening Notepad")
            os.system("notepad")
            break
        elif fingers == [0, 1, 1, 0, 0]:
            print("Opening Chrome")
            os.system("start chrome")
            break
        else:
            print("Unknown Gesture:", fingers)

    cv2.imshow("Webcam", img)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [0, 0, 0, 0, 0]
# Unknown Gesture: [0, 0, 0, 0, 0]
# Fingers Up: [1, 0, 0, 0, 0]
# Unknown Gesture: [1, 0, 0, 0, 0]
# Fingers Up: [1, 0, 0, 0, 0]
# Unknown Gesture: [1, 0, 0, 0, 0]
# Fingers Up: [1, 0, 0, 0, 0]
# Unknown Gesture: [1, 0, 0, 0, 0]
# Fingers Up: [1, 0, 0, 0, 0]
# Unknown Gesture: [1, 0, 0, 0, 0]
# Fingers Up: [1, 1, 0, 0, 0]
# Unknown Gesture: [1, 1, 0, 0, 0]
# Fingers Up: [1, 1, 0, 0, 0]
# Unknown Gesture: [1, 1, 0, 0, 0]
# Fingers Up: [1, 1, 0, 0, 0]
# Unknown Gesture: [1, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 0, 0, 0]
# Unknown Gesture: [0, 1, 0, 0, 0]
# Fingers Up: [0, 1, 1, 0, 0]
# Opening Chrome
